# %% [markdown]
# <a href="https://colab.research.google.com/github/alelasantillan/facebook-blender-bot/blob/master/BlenderBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Blender - Chit Chat Chatbot 90M
#
# ParlAI project site: https://parl.ai/projects/blender/
#
# Colab by Quantum Stat www.quantumstat.com

# %%
# !git clone https://github.com/facebookresearch/ParlAI.git
# Out:
# Cloning into 'ParlAI'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 30707 (delta 43), reused 49 (delta 23), pack-reused 30627
# Receiving objects: 100% (30707/30707), 58.66 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (21834/21834), done.

# %%
cd ParlAI/
# Out:
# /content/ParlAI

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating parlai.egg-info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing entry points to parlai.egg-info/entry_points.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/parlai.egg-link (link to .)
# Adding parlai 0.1.20200710 to easy-install.pth file
# Installing parlai script to /usr/local/bin
#
# Installed /content/ParlAI
# Processing dependencies for parlai==0.1.20200710
# Searching for websocket-server
# Reading https://pypi.org/simple/websocket-server/
# ...
# Best match: websocket-server 0.4
# Processing websocket_server-0.4.tar.gz
# Writing /tmp/easy_install-72mw1f7n/websocket_server-0.4/setup.cfg
# ...

# %%
# !pip install 'git+https://github.com/rsennrich/subword-nmt.git#egg=subword-nmt'
# Out:
# ...
#   Cloning https://github.com/rsennrich/subword-nmt.git to /tmp/pip-install-3tn9wdqv/subword-nmt
#   Running command git clone -q https://github.com/rsennrich/subword-nmt.git /tmp/pip-install-3tn9wdqv/subword-nmt
# ...
#   Created wheel for subword-nmt: filename=subword_nmt-0.3.7-cp36-none-any.whl size=130155 sha256=56cd0813279d5f3cdf78da07215ab34eb5944a8505e810eff34a26fb5a68dbc6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xtceu6f8/wheels/05/2b/3a/73cd213b79c18512c76a9ea40329a6819fa9276e232679d834
# Successfully built subword-nmt
# ...

# %% [markdown]
# # 90M Parameter Model

# %%
# !python parlai/scripts/safe_interactive.py -t blended_skill_talk -mf zoo:blender/blender_90M/model
# Out:
#                                  /@&%###%&&@@#
#                       .,*/((((##@@@&%%#%%&&@@@&%%#/*.
#              #@@&&&%%%%##(((///*****//(((###%%%&&&@@@@@&&%#%%#.
#          .%&@@@@@&&&%%%####((((////((((####%%%&&&@@@@@&&%%#%%####,
#            ./,,#(//**,,.....,,,,***////((((########%%%%%%%%###(((
#               /*(//**,,,....,,,,***////((((########%%%%%%%%###(#%*
#                (*,...      ...,,,***//////((((((///////(/*...,/#@@@(
#                **,,..         ...,,,,,,,,,,........,,*///*...*(#@@@@&&*
#                ./,,..          ...,,,,,,,,,........,,*//*,...*#/,,,,,/%#
#                 (*,..          ...,,,,,,,,,........,,*//*,..,/(      .,#(
#                 **,..          ...,,,,,,,,,.........,*//*,..,((       .,(#
#                  /*,..          ....,,,,,,,.....  ..,***,,,,(#         ..#&
#                  **,..          ....,,,,,,,....   ..,***,,,*#.         .,%@
#                  ./,...       B l e n d e r B o t ...***,,,*#          .*%@
# ...
